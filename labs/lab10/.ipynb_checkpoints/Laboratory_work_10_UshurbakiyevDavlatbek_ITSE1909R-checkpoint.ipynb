# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2 style="text-align:center;">Welcome to the tenth laboratory work in this course</h2>
# <h4 style="text-align:center;">This laboratory work is graded</h4>

# %% [markdown]
# <span style="color:#011f4b; font-size:15px"><b>The goal</b> of the laboratory work - is to get you familiar with Linear Regression models<br/>
# <br/>
# <span style="color:#011f4b;">
# Your task is to complete this laboratory work within 80 minutes and submit the .ipynb file to DL "Laboratory09".
# <br/>
# <b>Pay attention to the file name - your file should be named as "Laboratory_work_10_Yoursurname_YourName_yourgroup".</b> In case you didn't name your file properly (as showed before) <b>-5% penalty</b> will be applied.
# </span>

# %% [markdown]
# <hr/>

# %% [markdown]
# Today you will use 2 linear regression models from different packages (almost different)
# <br/><br/>
# <li><code>LinearRegression()</code>from <b> sklearn</b> package</li>
# <li><code>OLS()</code> (Ordinary Least Squares) from <b> statmodels</b> package</li>

# %% [markdown]
# You can find official documentation for each model
# <br/>
# [here](https://ogrisel.github.io/scikit-learn.org/sklearn-tutorial/tutorial/statistical_inference/supervised_learning.html#linear-regression)
# <br/>
# [here](https://www.statsmodels.org/devel/generated/statsmodels.regression.linear_model.OLS.html)

# %% [markdown]
# <b><span style="font-size:20px; color:orange">A</span>wesome</b>, now let's get started with laboratory work

# %% [markdown]
# <b>First things first,</b> import <code>pandas</code>, <code>sklearn</code>, <code>statmodels</code>, <code>numpy</code> and <code>matplotlib</code>packages to your notebook

# %%
# Import packages  pandas, numpy, matplotlib or seaborn here
import pandas as pd
import pandas.util.testing as tm
import numpy  as np
import seaborn as sns
# Out:
# <ipython-input-2-6b7b050cb169>:3: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# If you haven't install sklear package on your laptop - run the cell below before you will import packages

# %%
# run this cell

# LinearRegression()  model can be used from linear_model module
from sklearn import linear_model

# OSL() model can be used from statmodels package
import statsmodels.api as sm

# we will perform sampling using train_test_split module for training and testin set
# and we will use GridSearchCV to find the best parameters for SGDRegressor()
from sklearn.model_selection import train_test_split

from sklearn import preprocessing

# we will evaluate our models using RMSE(mean_squared_error) and Determination coefficient(r2_score)
from sklearn.metrics import mean_squared_error, r2_score

# in case you will use polinominal features
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# <b><span style="font-size:20px; color:orange">G</span>reat!</b>
# <br/>
# <b>Now</b> let's start with tasks:
# <br/>

# %% [markdown]
# <h3>TASK 1: DATAFRAME</h3>

# %% [markdown]
# <b>Task 1.1</b> Read csv file into dataframe, perform info(), head(), describe and any other necessary first step function

# %%
# Read your CSV file here
data = pd.read_csv('Lemonade_new.csv')

# %%
# Get first look at your data
data.shape
# Out:
# (365, 9)

# %%
# Get first look at your data
data.head()
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales  Season  \
# 0  2017-01-01     Sunday         27.0      2.00      15    0.3     10  Winter
# 1  2017-01-02     Monday         28.9      1.33      15    0.3     13  Winter
# 2  2017-01-03    Tuesday         34.5      1.33      27    0.3     15  Winter
# 3  2017-01-04  Wednesday         44.1      1.05      28    0.3     17  Winter
# 4  2017-01-05   Thursday         42.4      1.00      33    0.3     18  Winter
#
#    Revenue
# 0      3.0
# 1      3.9
# 2      4.5
# 3      5.1
# 4      5.4

# %%
# Get first look at your data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         365 non-null    object
#  1   Day          365 non-null    object
#  2   Temperature  365 non-null    float64
#  3   Rainfall     365 non-null    float64
#  4   Flyers       365 non-null    int64
#  5   Price        365 non-null    float64
#  6   Sales        365 non-null    int64
#  7   Season       365 non-null    object
#  8   Revenue      365 non-null    float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 21.4+ KB

# %%
data.isnull().sum()
# Out:
# Date           0
# Day            0
# Temperature    0
# Rainfall       0
# Flyers         0
# Price          0
# Sales          0
# Season         0
# Revenue        0
# dtype: int64

# %%
# Get first look at your data
data.describe().T
# Out:
#              count       mean        std    min    25%    50%    75%    max
# Temperature  365.0  60.731233  16.196266  15.10  49.70  61.10  71.30  102.9
# Rainfall     365.0   0.826603   0.273171   0.47   0.65   0.74   0.91    2.5
# Flyers       365.0  40.284932  13.178651   9.00  31.00  39.00  49.00   80.0
# Price        365.0   0.333973   0.075206   0.30   0.30   0.30   0.30    0.5
# Sales        365.0  25.323288   6.893589   7.00  20.00  25.00  30.00   43.0
# Revenue      365.0   8.722466   4.017536   2.10   6.00   7.50   9.30   21.5

# %%
data.Sales.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# How is your data doing?
# <br/> Do you have any <b>NaNs</b>? Categorical values?
# <br/>Inconsistent data formats - strings instead of float or int, for example?

# %% [markdown]
# Keep in mind - you will fit linear models today (based on math) and you cannot fit categorical data without encoding neither NaNs.

# %% [markdown]
# <h3> TASK 2: DATA PREPARATION</h3>

# %% [markdown]
# Prepare your data - <b>drop</b> or <b>restore</b> NaNs, outliers, fix inconsistent formats if any, divide your data into 2 groups - <b>categorical data</b> and <b>numerical data</b>.
# <br/>I highly recomend your to create 2 lists with column names as categorical() and numerical().

# %%
# Drop or restore Nans
data.dropna()
# Out:
#            Date        Day  Temperature  Rainfall  Flyers  Price  Sales  \
# 0    2017-01-01     Sunday         27.0      2.00      15    0.3     10
# 1    2017-01-02     Monday         28.9      1.33      15    0.3     13
# 2    2017-01-03    Tuesday         34.5      1.33      27    0.3     15
# 3    2017-01-04  Wednesday         44.1      1.05      28    0.3     17
# 4    2017-01-05   Thursday         42.4      1.00      33    0.3     18
# ..          ...        ...          ...       ...     ...    ...    ...
# 360  2017-12-27  Wednesday         42.7      1.00      33    0.3     19
# 361  2017-12-28   Thursday         37.8      1.25      32    0.3     16
# 362  2017-12-29     Friday         39.5      1.25      17    0.3     15
# 363  2017-12-30   Saturday         30.9      1.43      22    0.3     13
# 364  2017-12-31     Sunday         15.1      2.50       9    0.3      7
#
#      Season  Revenue
# 0    Winter      3.0
# 1    Winter      3.9
# 2    Winter      4.5
# 3    Winter      5.1
# 4    Winter      5.4
# ..      ...      ...
# 360  Winter      5.7
# 361  Winter      4.8
# 362  Winter      4.5
# 363  Winter      3.9
# 364  Winter      2.1
#
# [365 rows x 9 columns]

# %%
# Drop or restore Nans
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         365 non-null    object
#  1   Day          365 non-null    object
#  2   Temperature  365 non-null    float64
#  3   Rainfall     365 non-null    float64
#  4   Flyers       365 non-null    int64
#  5   Price        365 non-null    float64
#  6   Sales        365 non-null    int64
#  7   Season       365 non-null    object
#  8   Revenue      365 non-null    float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 21.4+ KB

# %%
# Drop outliers
data[['Rainfall']].boxplot()
# Out:
# <AxesSubplot:>

# %%
data[['Temperature']].boxplot()
# Out:
# <AxesSubplot:>

# %%
data[['Flyers']].boxplot()
# Out:
# <AxesSubplot:>

# %%
data.Price.unique()
# Out:
# array([0.3, 0.5])

# %%
data.columns
# Out:
# Index(['Date', 'Day', 'Temperature', 'Rainfall', 'Flyers', 'Price', 'Sales',
#        'Season', 'Revenue'],
#       dtype='object')

# %%
data.drop(data[data.Flyers > 76].index, inplace = True)
data.drop(data[data.Temperature < 20].index, inplace = True)
data.drop(data[data.Rainfall > 1.25].index, inplace = True)

# %%
# Any inconsistent data formats - fix them
data.Date = pd.to_datetime(data.Date, dayfirst=True )

# %%
# Categorical features
cat = ['Date', 'Day']

# %%
# Numerical features
num = ['Temperature', 'Rainfall', 'Flyers', 'Price', 'Sales']

# %% [markdown]
# <b>Great job!</b>
# <br/> Let's move on now
# <hr/>

# %% [markdown]
# <h3> TASK 2.2: MORE DATA PREPARATION</h3>

# %% [markdown]
# Usually you train(fit) your model on train data and then test your model on test data. It's really bad, baad idea to train and test on the same data - you model will simply overfit on train set.
# <br/>
# <b>So,</b> lets divide our data into two parts - <b>train part(70-80%) </b>and <b>test part(20-30%).</b>
# <br/>
# On Laboratory work 6 you have learned how to random sample your data, and you can use that function here, but to save your time I recommend you to use <code>train_test_split()</code> model.
# <br/>
# As it says, this model will divide our data into 4 parts - independent variables for train set, target variable for train set, independent variables for test set, target variable for test set.
# <br/>
# <b>Aham - before you have to divide your data into independent variables and target variables, or simply X and Y.<b>

# %% [markdown]
# <h4>For this task you can use only numerical data, unless you already have encoded your categorical data. If you didn't - don't worry you will do it on task 4</h4>

# %% [markdown]
# TARGET VALUE - <b>Sales</b>

# %%
# your X dataframe - independent variables
X = data[['Temperature', 'Rainfall', 'Flyers', 'Price']].copy()

# %%
data.head(2)
# Out:
#         Date        Day  Temperature  Rainfall  Flyers  Price  Sales  Season  \
# 3 2017-01-04  Wednesday         44.1      1.05      28    0.3     17  Winter
# 4 2017-01-05   Thursday         42.4      1.00      33    0.3     18  Winter
#
#    Revenue
# 3      5.1
# 4      5.4

# %%
Y = data[['Sales']].copy()

# %% [markdown]
# Features: 'Date', 'Day', 'Temperature', 'Rainfall', 'Flyers', 'Price'
# <br/>
# Target Value: 'Sales'

# %%
# Now, check the shapes, run this cell
X.shape, Y.shape
# Out:
# ((335, 4), (335, 1))

# %%
# run this cell, but before, ensure you have divided your initial data into X and Y dataframes
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42 )

# %%
# Check shapes of new datasets, run this cell
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((234, 4), (234, 1), (101, 4), (101, 1))

# %% [markdown]
# <h3> TASK 3: MODELS</h3>

# %% [markdown]
# <b> Task 3.1</b> OLS() model. Carefully eximine each cell and run it.

# %%
x_train_ols =  sm.add_constant(x_train)

# %%
# run this cell
ols_model = sm.OLS(y_train, x_train, missing="drop").fit()

# %%
# run this cell
y_predicted_ols=ols_model.predict(x_test)

# %%
y_predicted_ols.shape, y_test.shape
# Out:
# ((101,), (101, 1))

# %% [markdown]
# Awesome,
# <br/>
# <b>R-squared</b> is also called the coefficient of determination. It’s a statistical measure of how well the regression line fits the data.

# %% [markdown]
# As you see before - to train your model you have to <b>use fit()</b> function, literally - put your data into model, with x_train and y_train - your model 'teaches' itsel to produce results as close as possible to y_train using x_train.
# <br/> Well, not really 'teaches' - let's say adjustes its coefficients and runs math-c machine to create as perfect as possible model (equation)

# %% [markdown]
# <b> Task 3.2</b> LinearRegression() model. Carefully eximine each cell and run it.

# %%
# Create the instance of your model - run this cell
lr_model = linear_model.LinearRegression()

# %%
# train it - run this cell
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# predict your target value - y's
y_predicted_ls = lr_model.predict(x_test)

# %% [markdown]
# <b> Task 3.3</b> Now, lets evaluate how good your models are. Compare

# %%
# run this cell
print("MSE of OLS() vs LinearRegression():\n")
mean_squared_error(y_test, y_predicted_ols), mean_squared_error(y_test, y_predicted_ls)
# Out:
# MSE of OLS() vs LinearRegression():
# (0.9427001061911993, 0.8436041816810043)

# %%
# run this cell
print("R-square of OLS() vs LinearRegression():\n")
r2_score(y_test, y_predicted_ols), r2_score(y_test, y_predicted_ls)
# Out:
# R-square of OLS() vs LinearRegression():
# (0.9759877253328328, 0.9785118775442394)

# %% [markdown]
# Which model performs better? <br/> How did you know that?

# %% [markdown]
# Let's see details about our models:

# %%
# run this cell
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Sales   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                          4.717e+04
# Date:                Tue, 27 Apr 2021   Prob (F-statistic):                        0.00
# Time:                        22:02:05   Log-Likelihood:                         -316.13
# No. Observations:                 234   AIC:                                      640.3
# Df Residuals:                     230   BIC:                                      654.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Temperature     0.3949      0.007     58.742      0.000       0.382       0.408
# Rainfall       -0.5965      0.206     -2.898      0.004      -1.002      -0.191
# Flyers          0.0217      0.008      2.817      0.005       0.007       0.037
# Price           2.8504      0.943      3.023      0.003       0.993       4.708
# ==============================================================================
# Omnibus:                       56.966   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               11.517
# Skew:                           0.106   Prob(JB):                      0.00316
# Kurtosis:                       1.934   Cond. No.                     1.18e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# run this cell
lr_model.coef_
# Out:
# array([[ 0.31792742, -6.98867258,  0.01365059,  2.96371783]])

# %% [markdown]
# y = 0.371 * Temperature + (-2.178 * Rainfall) + 0.021 * Flyers + 2.293 * Price + 2.894

# %%
lr_model.intercept_
# Out:
# array([10.07643095])

# %%
y = 0.371 * 0.3949 + (-2.178 * -0.5965) + 0.021 * 0.0217 + 2.293 * 2.8504 + 2.894

# %% [markdown]
# <h3> Underfit ? Overfit</h3>

# %%
print('Score on train set:', lr_model.score(x_train, y_train))
# Out:
# Score on train set: 0.9795218303551783

# %%
print('Score on test set:', lr_model.score(x_test, y_test))
# Out:
# Score on test set: 0.9785118775442394

# %%
print('No Underfit Neighter Overfit')
# Out:
# No Underfit Neighter Overfit

# %% [markdown]
# <hr/>

# %% [markdown]
# <h2> Dummy Model</h2>

# %%
lr_model.score(x_test, y_test)
# Out:
# 0.9785118775442394

# %% [markdown]
# <hr/>

# %%
from sklearn.dummy import DummyClassifier
from sklearn.dummy import DummyRegressor

# %%
dummy_clf = DummyClassifier()

# %%
dummy_clf.fit(x_train, y_train)
# Out:
# DummyClassifier()

# %%
y_dummy_cl = dummy_clf.predict(x_test)

# %%
mean_squared_error(y_test, y_dummy_cl), r2_score(y_test,  y_dummy_cl)
# Out:
# (41.960396039603964, -0.06880708745961117)

# %%
dummy_clf.score(x_test, y_test)
# Out:
# 0.07920792079207921

# %%
dummy_regr = DummyRegressor(strategy="median")

# %%
dummy_regr.fit(x_train, y_train)
# Out:
# DummyRegressor(strategy='median')

# %%
y_dummy_regr =  dummy_regr.predict(x_test)

# %%
dummy_regr.score(x_test, y_test)
# Out:
# -0.010549787506055175

# %%
mean_squared_error(y_test, y_dummy_regr), r2_score(y_test,  y_dummy_regr)
# Out:
# (39.67326732673267, -0.010549787506055175)

# %% [markdown]
# Proceed to Task 3.4 if you feel yourself very comfortable with today's laboratory work. If not - you can complete it next week

# %% [markdown]
# <b> Task 3.4* </b> Cheaking the goodnes of model just by scores on test data is good, but not enough - our model can....overfit or underfit

# %% [markdown]
# [Read mode here](https://scikit-learn.org/stable/auto_examples/model_selection/plot_underfitting_overfitting.html?highlight=overfitting) - use cross validation without pipeline (not really need it now)

# %%
# run this cell 
from sklearn.model_selection import cross_val_score
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from statsmodels import regression
from scipy import poly1d

# %%
# check on overfit of OLS model
x1 = y_test.values
y1 = y_predicted_ols.values
x1 = x1.flatten()
y1 = y1.flatten()

xs = np.linspace(-0.25, 9.25, 200)

lin = np.polyfit(x1, y1, 1)
quad = np.polyfit(x1, y1, 2)
many = np.polyfit(x1, y1, 9)

plt.scatter(x1, y1)
plt.plot(xs, poly1d(lin)(xs))
plt.plot(xs, poly1d(quad)(xs))
plt.plot(xs, poly1d(many)(xs))
plt.ylabel('Y')
plt.xlabel('X')
plt.legend(['Underfit', 'Good fit', 'Overfit']);

# %%
# check on overfit of LS model
x2 = y_test.values
y2 = y_predicted_ls.ravel()
x2 = x2.flatten()

xs = np.linspace(-0.05, 8.25, 100)

lin = np.polyfit(x2, y2, 1)
quad = np.polyfit(x2, y2, 4)
many = np.polyfit(x2, y2, 9)

plt.scatter(x2, y2)
plt.plot(xs, poly1d(lin)(xs))
plt.plot(xs, poly1d(quad)(xs))
plt.plot(xs, poly1d(many)(xs))
plt.ylabel('Y')
plt.xlabel('X')
plt.legend(['Underfit', 'Good fit', 'Overfit']);

# %% [markdown]
# Compare the coefficients.

# %% [markdown]
# <b><span style="font-size:14px; color:orange">G</span>reat!</b>
# <br/>
# <b>Now</b> let's think how to improve our model:
# <br/>

# %% [markdown]
# <h3> TASK 4: ITS ALL ABOUT DATA</h3>

# %% [markdown]
# <b> Task 4.1 </b> Encode your categorical features to fit them into the model

# %%
# Your text goes here
LabelEncoder_ = preprocessing.LabelEncoder()

# %%
# Your text goes here
Y.Sales = LabelEncoder_.fit_transform(Y.Sales)

# %% [markdown]
# <b> Task 4.2 </b> Analyze correlation coefficients - to see if there any features you better exclude from model

# %%
# Your text goes here
data.corr()
# Out:
#              Temperature  Rainfall    Flyers     Price     Sales   Revenue
# Temperature     1.000000 -0.939208  0.734235  0.522043  0.986723  0.823360
# Rainfall       -0.939208  1.000000 -0.722124 -0.460797 -0.950604 -0.756095
# Flyers          0.734235 -0.722124  1.000000  0.391624  0.742350  0.616535
# Price           0.522043 -0.460797  0.391624  1.000000  0.530101  0.905117
# Sales           0.986723 -0.950604  0.742350  0.530101  1.000000  0.834523
# Revenue         0.823360 -0.756095  0.616535  0.905117  0.834523  1.000000

# %%
# Your text goes here
data.corr(method = 'spearman')
# Out:
#              Temperature  Rainfall    Flyers     Price     Sales   Revenue
# Temperature     1.000000 -0.974363  0.711941  0.531647  0.983796  0.964060
# Rainfall       -0.974363  1.000000 -0.724217 -0.546412 -0.989899 -0.972911
# Flyers          0.711941 -0.724217  1.000000  0.383674  0.724543  0.710570
# Price           0.531647 -0.546412  0.383674  1.000000  0.546259  0.669345
# Sales           0.983796 -0.989899  0.724543  0.546259  1.000000  0.981745
# Revenue         0.964060 -0.972911  0.710570  0.669345  0.981745  1.000000

# %%
sns.scatterplot(data.Rainfall, data.Sales)
# Out:
# c:\users\dushu\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rainfall', ylabel='Sales'>

# %%
data['Rainfall'] = 1 / data.Rainfall

# %%
data['Rainfall'] = np.log(data.Rainfall)

# %%
sns.scatterplot(data.Rainfall, data.Sales)
# Out:
# c:\users\dushu\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rainfall', ylabel='Sales'>

# %%
data['Month'] = data.Date.dt.month

# %%
data['Day_'] = data.Day.map({'Sunday':7, 'Monday':1, 'Tuesday':2, 'Wednesday':3, 'Thursday':4, 'Friday':5,
       'Saturday':6})

# %%
data.Day.unique()
# Out:
# array(['Wednesday', 'Thursday', 'Sunday', 'Monday', 'Tuesday', 'Saturday',
#        'Friday'], dtype=object)

# %%
data.head()
# Out:
#         Date        Day  Temperature  Rainfall  Flyers  Price  Sales  Season  \
# 3 2017-01-04  Wednesday         44.1 -0.048790      28    0.3     17  Winter
# 4 2017-01-05   Thursday         42.4  0.000000      33    0.3     18  Winter
# 7 2017-01-08     Sunday         37.5 -0.165514      28    0.3     15  Winter
# 8 2017-01-09     Monday         38.1 -0.165514      20    0.3     17  Winter
# 9 2017-01-10    Tuesday         43.4 -0.048790      33    0.3     18  Winter
#
#    Revenue  Month  Day_
# 3      5.1      1     3
# 4      5.4      1     4
# 7      4.5      1     7
# 8      5.1      1     1
# 9      5.4      1     2

# %%
data_1 = pd.DataFrame(preprocessing.normalize(data[num]))

# %%
data_1.columns = num

# %%
data_1.head()
# Out:
#    Temperature  Rainfall    Flyers     Price     Sales
# 0     0.802761 -0.000888  0.509689  0.005461  0.309454
# 1     0.748266  0.000000  0.582377  0.005294  0.317660
# 2     0.763027 -0.003368  0.569727  0.006104  0.305211
# 3     0.823463 -0.003577  0.432264  0.006484  0.367425
# 4     0.755881 -0.000850  0.574748  0.005225  0.313499

# %% [markdown]
# <b> Task 4.3 </b> Analyze data - if you can use polynomial features [read more](https://scikit-learn.org/stable/modules/linear_model.html#polynomial-regression-extending-linear-models-with-basis-functions)

# %%
# Your text goes here
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics

# %%
# Your text goes here
clf = Perceptron(fit_intercept=False, max_iter=10, tol=None,
                 shuffle=False).fit(PolynomialFeatures().fit_transform(x_train).astype(int), y_train.values.ravel())

# %%
# Your text goes here
clf.predict(PolynomialFeatures().fit_transform(x_train).astype(int))
# Out:
# array([25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 28, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 28, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 28, 25, 25,
#        25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 28, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#        25, 25, 25, 28, 25, 25, 28, 25, 25, 25, 25, 25, 25], dtype=int64)

# %%
clf.score(PolynomialFeatures().fit_transform(x_train).astype(int), y_train.values.ravel())
# Out:
# 0.1111111111111111

# %% [markdown]
# <b> Task 4.4 </b> Re-train your models with updated data and compare the metrics

# %%
# train LinearRegression model
OLS_model = sm.OLS(y_train, x_train).fit()

# %%
# predict with OLS
y_predicted_ols=ols_model.predict(x_test)

# %%
# predict with LinearRegression
y_predicted_ls = lr_model.predict(x_test)

# %%
# compare their metrics
print("MSE of OLS() vs LinearRegression():\n")
mean_squared_error(y_test, y_predicted_ols), mean_squared_error(y_test, y_predicted_ls)
# Out:
# MSE of OLS() vs LinearRegression():
# (0.9427001061911993, 0.8436041816810043)

# %% [markdown]
# <h3> TASK 5: CROSS - VALIDATION</h3>

# %%
# your text goes here

# %%
from sklearn.feature_selection import SelectKBest, f_regression

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
skbest = SelectKBest(score_func=f_regression, k = 5)
model = KNeighborsClassifier(n_neighbors=1)

# %%
import pandas as pd

# %%
df = pd.read_excel('Real_estate_valuation_data_set.xlsx')

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
 y = data.Sales

# %%
model.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
df['Y house price of unit area'] = df['Y house price of unit area'].astype(int)

# %%
ind = skbest.get_support()

# %%
model
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
X.columns[ind]
# Out:
# Index(['X2 house age', 'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude'],
#       dtype='object')

# %%
ind

# %%
X = df.iloc[:, :-1]

# %%
y = df['Y house price of unit area']

# %%
X
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1          2012.916667          32.0
# 1      2          2012.916667          19.5
# 2      3          2013.583333          13.3
# 3      4          2013.500000          13.3
# 4      5          2012.833333           5.0
# ..   ...                  ...           ...
# 409  410          2013.000000          13.7
# 410  411          2012.666667           5.6
# 411  412          2013.250000          18.8
# 412  413          2013.000000           8.1
# 413  414          2013.500000           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude
# 0       24.98298     121.54024
# 1       24.98034     121.53951
# 2       24.98746     121.54391
# 3       24.98746     121.54391
# 4       24.97937     121.54245
# ..           ...           ...
# 409     24.94155     121.50381
# 410     24.97433     121.54310
# 411     24.97923     121.53986
# 412     24.96674     121.54067
# 413     24.97433     121.54310
#
# [414 rows x 7 columns]

# %%
y
# Out:
# 0      37
# 1      42
# 2      47
# 3      54
# 4      43
#        ..
# 409    15
# 410    50
# 411    40
# 412    52
# 413    63
# Name: Y house price of unit area, Length: 414, dtype: int32

# %%
cross_res = cross_val_score(model, X, y, cv=4)
# Out:
# c:\users\dushu\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(("The least populated class in y has only %d"

# %%
cross_res
# Out:
# array([0.11538462, 0.07692308, 0.01941748, 0.01941748])

# %%
-----------------------------------------------------

# %%
data = pd.read_csv('Portugal_1.csv', delimiter=';')

# %%
data.head()
# Out:
#        ID         hotel  canceled  year      month  week number  day  \
# 0  104974    City Hotel         0  2017    January            4   25
# 1   77256    City Hotel         1  2015  September           39   20
# 2  115745    City Hotel         0  2017       July           27    6
# 3   25457  Resort Hotel         0  2016       June           26   25
# 4   39243  Resort Hotel         0  2017     August           32    7
#
#    weekend nights stays  week nights stays  adults  children meal country  \
# 0                     0                  2       1       0.0   BB     PRT
# 1                     2                  0       1       0.0   BB     PRT
# 2                     1                  3       1       1.0   BB     PRT
# 3                     2                  1       2       0.0   BB     PRT
# 4                     1                  4       2       0.0   BB     ESP
#
#    repeated guest     deposit  agent         customer reservation status  \
# 0               0  No Deposit    NaN  Transient-Party          Check-Out
# 1               0  Non Refund   78.0        Transient           Canceled
# 2               0  No Deposit    9.0  Transient-Party          Check-Out
# 3               0         NaN    NaN        Transient          Check-Out
# 4               0  No Deposit  240.0        Transient          Check-Out
#
#   reservation status date
# 0              2017-01-27
# 1              2015-09-15
# 2              2017-07-10
# 3              2016-06-28
# 4              2017-08-12

# %%
data.isnull().sum()
# Out:
# ID                             0
# hotel                          0
# canceled                       0
# year                           0
# month                          0
# week number                    0
# day                            0
# weekend nights stays           0
# week nights stays              0
# adults                         0
# children                       2
# meal                           0
# country                      292
# repeated guest                 0
# deposit                    10851
# agent                       9795
# customer                       0
# reservation status             0
# reservation status date        0
# dtype: int64

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52240 entries, 1 to 71523
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       52240 non-null  int64
#  1   hotel                    52240 non-null  object
#  2   canceled                 52240 non-null  int64
#  3   year                     52240 non-null  int64
#  4   month                    52240 non-null  object
#  5   week number              52240 non-null  int64
#  6   day                      52240 non-null  int64
#  7   weekend nights stays     52240 non-null  int64
#  8   week nights stays        52240 non-null  int64
#  9   adults                   52240 non-null  int64
#  10  children                 52240 non-null  float64
#  11  meal                     52240 non-null  object
#  12  country                  52240 non-null  object
#  13  repeated guest           52240 non-null  int64
#  14  deposit                  52240 non-null  object
#  15  agent                    52240 non-null  float64
#  16  customer                 52240 non-null  object
#  17  reservation status       52240 non-null  object
#  18  reservation status date  52240 non-null  object
# dtypes: float64(2), int64(9), object(8)
# memory usage: 6.4+ MB

# %%
data.describe().T
# Out:
#                         count          mean           std     min       25%  \
# ID                    52240.0  61107.853848  34221.088299     8.0  32954.75
# canceled              52240.0      0.391099      0.488001     0.0      0.00
# year                  52240.0   2016.157906      0.705982  2015.0   2016.00
# week number           52240.0     27.293913     13.284179     1.0     17.00
# day                   52240.0     15.803025      8.793386     1.0      8.00
# weekend nights stays  52240.0      0.976302      0.997889     0.0      0.00
# week nights stays     52240.0      2.584820      1.890351     0.0      1.00
# adults                52240.0      1.904632      0.468067     0.0      2.00
# children              52240.0      0.111658      0.412938     0.0      0.00
# repeated guest        52240.0      0.012921      0.112935     0.0      0.00
# agent                 52240.0     86.148794    110.625429     1.0      9.00
#
#                           50%       75%       max
# ID                    61087.5  90813.25  119389.0
# canceled                  0.0      1.00       1.0
# year                   2016.0   2017.00    2017.0
# week number              28.0     38.00      53.0
# day                      16.0     24.00      31.0
# weekend nights stays      1.0      2.00      16.0
# week nights stays         2.0      3.00      40.0
# adults                    2.0      2.00      26.0
# children                  0.0      0.00      10.0
# repeated guest            0.0      0.00       1.0
# agent                    14.0    229.00     535.0

# %%
i = 0
j = 0
while i < data.shape[1]: 
 if (data.iloc[:, i].dtype == 'int64' or data.iloc[:, i].dtype == 'float64'):
  j += 1
 i += 1
print('numerical -', j)
# Out:
# numerical - 11

# %%
i = 0
j = 0
while i < data.shape[1]: 
 if (data.iloc[:, i].dtype == 'object'):
  j += 1
 i += 1
print('categorical -', j)
# Out:
# categorical - 8

# %%
i = 0
sum = 0
while i < data.shape[1]:  
 if (data[str(data.iloc[:, i].name)].isnull().any()):   
  print('column -',str(data.iloc[:, i].name),' - have:', data[str(data.iloc[:, i].name)].isnull().sum(), 'NaN Data')
 sum += data[str(data.iloc[:, i].name)].isna().sum()
 i += 1 
print('Total NaNs -', sum)
# Out:
# Total NaNs - 0

# %%
data['weekend nights stays'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
i = 0
j = 0
k = 0
s = 0
print('less than min - outliers')
while i < data.shape[1]:  
 if (data.iloc[:, i].dtype == 'int64' or data.iloc[:, i].dtype == 'float64'):
  dataTrueLess = data[str(data.iloc[:, i].name)] < (Q1[str(data.iloc[:, i].name)] - (1.5 * IQR[str(data.iloc[:, i].name)]))
  for k in dataTrueLess.index:
    if (dataTrueLess[k]): 
      print(str(data.iloc[:, i].name), 'index -',k,', value -',  data[str(data.iloc[:, i].name)][k])
 i += 1 
print('----------------------------------------------------')   
print('more than max - outliers')
while j < data.shape[1]:  
 if (data.iloc[:, j].dtype == 'int64' or data.iloc[:, j].dtype == 'float64'): 
  dataTrueMore = data[str(data.iloc[:, j].name)] > (Q3[str(data.iloc[:, j].name)] + (1.5 * IQR[str(data.iloc[:, j].name)]))
  for s in dataTrueMore.index:
    if (dataTrueMore[s]): 
      print(str(data.iloc[:, j].name), 'index -',s,', value -',  data[str(data.iloc[:, j].name)][s])
 j += 1
# Out:
# less than min - outliers
# adults index - 1 , value - 1
# adults index - 2 , value - 1
# adults index - 10 , value - 1
# adults index - 14 , value - 1
# adults index - 15 , value - 1
# adults index - 22 , value - 1
# adults index - 23 , value - 1
# adults index - 34 , value - 1
# adults index - 42 , value - 1
# adults index - 59 , value - 1
# adults index - 65 , value - 1
# adults index - 66 , value - 1
# adults index - 97 , value - 1
# adults index - 105 , value - 1
# adults index - 108 , value - 1
# adults index - 114 , value - 1
# adults index - 118 , value - 1
# adults index - 123 , value - 1
# adults index - 128 , value - 1
# adults index - 133 , value - 1
# adults index - 149 , value - 1
# adults index - 162 , value - 1
# adults index - 168 , value - 1
# adults index - 201 , value - 1
# adults index - 207 , value - 1
# adults index - 223 , value - 1
# adults index - 239 , value - 1
# adults index - 268 , value - 1
# adults index - 277 , value - 1
# adults index - 296 , value - 1
# adults index - 310 , value - 1
# adults index - 314 , value - 1
# adults index - 326 , value - 1
# adults index - 327 , value - 1
# adults index - 338 , value - 1
# adults index - 354 , value - 1
# adults index - 361 , value - 1
# adults index - 371 , value - 1
# adults index - 373 , value - 1
# adults index - 379 , value - 1
# adults index - 384 , value - 1
# adults index - 386 , value - 1
# adults index - 393 , value - 1
# adults index - 394 , value - 1
# adults index - 398 , value - 1
# adults index - 420 , value - 1
# adults index - 425 , value - 1
# adults index - 437 , value - 1
# adults index - 441 , value - 1
# adults index - 443 , value - 1
# adults index - 455 , value - 1
# adults index - 456 , value - 1
# adults index - 459 , value - 1
# adults index - 462 , value - 1
# adults index - 470 , value - 1
# adults index - 478 , value - 1
# adults index - 484 , value - 1
# adults index - 496 , value - 1
# adults index - 511 , value - 1
# adults index - 514 , value - 1
# adults index - 517 , value - 1
# adults index - 522 , value - 1
# adults index - 533 , value - 1
# adults index - 543 , value - 1
# adults index - 550 , value - 1
# adults index - 561 , value - 1
# adults index - 576 , value - 1
# adults index - 579 , value - 1
# adults index - 582 , value - 1
# adults index - 589 , value - 1
# adults index - 593 , value - 1
# adults index - 594 , value - 1
# adults index - 595 , value - 1
# adults index - 601 , value - 1
# adults index - 605 , value - 1
# adults index - 617 , value - 1
# adults index - 627 , value - 1
# adults index - 647 , value - 1
# adults index - 657 , value - 1
# adults index - 662 , value - 1
# adults index - 672 , value - 1
# adults index - 676 , value - 1
# adults index - 690 , value - 1
# adults index - 700 , value - 1
# adults index - 712 , value - 1
# adults index - 715 , value - 1
# adults index - 737 , value - 1
# adults index - 744 , value - 1
# adults index - 748 , value - 1
# adults index - 777 , value - 1
# adults index - 789 , value - 1
# adults index - 2831 , value - 1
# adults index - 2840 , value - 1
# adults index - 2852 , value - 1
# adults index - 2861 , value - 1
# adults index - 2873 , value - 1
# adults index - 2877 , value - 1
# adults index - 2893 , value - 1
# adults index - 2899 , value - 1
# adults index - 2908 , value - 1
# adults index - 2913 , value - 1
# adults index - 2917 , value - 1
# adults index - 2928 , value - 1
# adults index - 2929 , value - 1
# adults index - 2949 , value - 1
# adults index - 2966 , value - 1
# adults index - 2975 , value - 1
# adults index - 2982 , value - 1
# adults index - 2983 , value - 1
# adults index - 2990 , value - 1
# adults index - 2992 , value - 1
# adults index - 2996 , value - 1
# adults index - 3011 , value - 1
# adults index - 3012 , value - 1
# adults index - 3030 , value - 1
# adults index - 3038 , value - 1
# adults index - 3065 , value - 1
# adults index - 3066 , value - 1
# adults index - 3084 , value - 1
# adults index - 3086 , value - 1
# adults index - 3094 , value - 1
# adults index - 3103 , value - 1
# adults index - 3118 , value - 1
# adults index - 3119 , value - 1
# adults index - 3133 , value - 1
# adults index - 3135 , value - 1
# adults index - 3146 , value - 1
# adults index - 3153 , value - 1
# adults index - 3158 , value - 1
# adults index - 3162 , value - 1
# adults index - 3185 , value - 1
# adults index - 3199 , value - 1
# adults index - 3200 , value - 1
# adults index - 3212 , value - 1
# adults index - 3237 , value - 1
# adults index - 3241 , value - 1
# adults index - 3245 , value - 1
# adults index - 3247 , value - 1
# adults index - 3250 , value - 1
# adults index - 3252 , value - 1
# adults index - 3280 , value - 1
# adults index - 3283 , value - 1
# adults index - 3285 , value - 1
# adults index - 3290 , value - 1
# adults index - 3307 , value - 1
# adults index - 3321 , value - 1
# adults index - 3324 , value - 1
# adults index - 3338 , value - 1
# adults index - 3359 , value - 1
# adults index - 3369 , value - 0
# adults index - 3370 , value - 1
# adults index - 3395 , value - 1
# adults index - 3402 , value - 1
# adults index - 3429 , value - 1
# adults index - 3443 , value - 1
# adults index - 3444 , value - 1
# adults index - 3446 , value - 1
# adults index - 3456 , value - 1
# adults index - 3464 , value - 1
# adults index - 3468 , value - 1
# adults index - 3473 , value - 0
# adults index - 3480 , value - 1
# adults index - 3483 , value - 1
# adults index - 3485 , value - 1
# adults index - 3494 , value - 1
# adults index - 3511 , value - 1
# adults index - 3514 , value - 1
# adults index - 3516 , value - 1
# adults index - 3526 , value - 1
# adults index - 3549 , value - 1
# adults index - 3552 , value - 1
# adults index - 3561 , value - 1
# adults index - 3562 , value - 1
# adults index - 3565 , value - 1
# adults index - 3582 , value - 1
# adults index - 3586 , value - 1
# adults index - 3587 , value - 1
# adults index - 3594 , value - 1
# adults index - 3603 , value - 1
# adults index - 3610 , value - 1
# adults index - 3645 , value - 1
# adults index - 3648 , value - 1
# adults index - 3651 , value - 1
# adults index - 3662 , value - 1
# adults index - 3664 , value - 1
# adults index - 3666 , value - 1
# adults index - 3669 , value - 1
# adults index - 3671 , value - 1
# adults index - 3682 , value - 1
# adults index - 3698 , value - 1
# adults index - 3715 , value - 1
# adults index - 3716 , value - 1
# adults index - 3718 , value - 1
# adults index - 3720 , value - 1
# adults index - 3724 , value - 1
# adults index - 13054 , value - 1
# adults index - 13055 , value - 1
# adults index - 13061 , value - 1
# adults index - 13072 , value - 1
# adults index - 13088 , value - 1
# adults index - 13102 , value - 1
# adults index - 13104 , value - 1
# adults index - 13112 , value - 1
# adults index - 13113 , value - 1
# adults index - 13117 , value - 1
# adults index - 13136 , value - 1
# adults index - 13137 , value - 1
# adults index - 13141 , value - 1
# adults index - 13146 , value - 1
# adults index - 13172 , value - 1
# adults index - 13181 , value - 1
# adults index - 13190 , value - 1
# adults index - 13197 , value - 1
# adults index - 13206 , value - 1
# adults index - 13209 , value - 1
# adults index - 13216 , value - 1
# adults index - 13223 , value - 1
# adults index - 13224 , value - 1
# adults index - 13228 , value - 1
# adults index - 13237 , value - 1
# adults index - 13257 , value - 1
# adults index - 13259 , value - 1
# adults index - 13266 , value - 1
# adults index - 13276 , value - 1
# adults index - 13278 , value - 1
# adults index - 13331 , value - 1
# adults index - 13332 , value - 1
# adults index - 13337 , value - 1
# adults index - 13345 , value - 1
# adults index - 13350 , value - 1
# adults index - 13361 , value - 1
# adults index - 13368 , value - 1
# adults index - 13386 , value - 1
# adults index - 13409 , value - 1
# adults index - 13418 , value - 1
# adults index - 13427 , value - 1
# adults index - 13440 , value - 1
# adults index - 13453 , value - 1
# adults index - 13455 , value - 1
# adults index - 13456 , value - 1
# adults index - 13472 , value - 1
# adults index - 13491 , value - 1
# adults index - 13494 , value - 1
# adults index - 13500 , value - 1
# adults index - 13505 , value - 1
# ...
# repeated guest index - 28052 , value - 1
# repeated guest index - 28214 , value - 1
# repeated guest index - 28215 , value - 1
# repeated guest index - 28240 , value - 1
# repeated guest index - 28392 , value - 1
# repeated guest index - 28439 , value - 1
# repeated guest index - 28511 , value - 1
# repeated guest index - 28791 , value - 1
# repeated guest index - 29032 , value - 1
# repeated guest index - 29286 , value - 1
# repeated guest index - 29674 , value - 1
# repeated guest index - 29738 , value - 1
# repeated guest index - 29753 , value - 1
# repeated guest index - 29759 , value - 1
# repeated guest index - 29773 , value - 1
# repeated guest index - 29789 , value - 1
# repeated guest index - 30031 , value - 1
# repeated guest index - 30142 , value - 1
# repeated guest index - 30346 , value - 1
# repeated guest index - 30552 , value - 1
# repeated guest index - 30659 , value - 1
# repeated guest index - 30869 , value - 1
# repeated guest index - 30900 , value - 1
# repeated guest index - 31008 , value - 1
# repeated guest index - 31132 , value - 1
# repeated guest index - 31149 , value - 1
# repeated guest index - 31150 , value - 1
# repeated guest index - 31153 , value - 1
# repeated guest index - 31155 , value - 1
# repeated guest index - 31194 , value - 1
# repeated guest index - 31246 , value - 1
# repeated guest index - 31259 , value - 1
# repeated guest index - 31335 , value - 1
# repeated guest index - 31337 , value - 1
# repeated guest index - 31533 , value - 1
# repeated guest index - 31815 , value - 1
# repeated guest index - 31865 , value - 1
# repeated guest index - 31923 , value - 1
# repeated guest index - 31991 , value - 1
# repeated guest index - 32013 , value - 1
# repeated guest index - 32063 , value - 1
# repeated guest index - 32265 , value - 1
# repeated guest index - 32369 , value - 1
# repeated guest index - 32371 , value - 1
# repeated guest index - 32505 , value - 1
# repeated guest index - 32582 , value - 1
# repeated guest index - 32635 , value - 1
# repeated guest index - 32720 , value - 1
# repeated guest index - 32798 , value - 1
# repeated guest index - 32931 , value - 1
# repeated guest index - 32963 , value - 1
# repeated guest index - 33174 , value - 1
# repeated guest index - 33252 , value - 1
# repeated guest index - 33563 , value - 1
# repeated guest index - 33613 , value - 1
# repeated guest index - 33677 , value - 1
# repeated guest index - 33696 , value - 1
# repeated guest index - 33713 , value - 1
# repeated guest index - 33832 , value - 1
# repeated guest index - 33889 , value - 1
# repeated guest index - 33938 , value - 1
# repeated guest index - 33953 , value - 1
# repeated guest index - 33978 , value - 1
# repeated guest index - 33981 , value - 1
# repeated guest index - 34028 , value - 1
# repeated guest index - 34112 , value - 1
# repeated guest index - 34528 , value - 1
# repeated guest index - 34552 , value - 1
# repeated guest index - 34754 , value - 1
# repeated guest index - 34795 , value - 1
# repeated guest index - 35026 , value - 1
# repeated guest index - 35137 , value - 1
# repeated guest index - 35288 , value - 1
# repeated guest index - 35357 , value - 1
# repeated guest index - 35362 , value - 1
# repeated guest index - 35403 , value - 1
# repeated guest index - 35464 , value - 1
# repeated guest index - 35548 , value - 1
# repeated guest index - 35626 , value - 1
# repeated guest index - 35762 , value - 1
# repeated guest index - 35826 , value - 1
# repeated guest index - 35974 , value - 1
# repeated guest index - 36179 , value - 1
# repeated guest index - 36244 , value - 1
# repeated guest index - 36503 , value - 1
# repeated guest index - 36550 , value - 1
# repeated guest index - 36680 , value - 1
# repeated guest index - 36732 , value - 1
# repeated guest index - 36773 , value - 1
# repeated guest index - 37000 , value - 1
# repeated guest index - 37087 , value - 1
# repeated guest index - 37272 , value - 1
# repeated guest index - 37543 , value - 1
# repeated guest index - 37627 , value - 1
# repeated guest index - 37774 , value - 1
# repeated guest index - 37802 , value - 1
# repeated guest index - 38077 , value - 1
# repeated guest index - 38103 , value - 1
# repeated guest index - 38140 , value - 1
# repeated guest index - 38167 , value - 1
# repeated guest index - 38343 , value - 1
# repeated guest index - 38586 , value - 1
# repeated guest index - 38782 , value - 1
# repeated guest index - 38794 , value - 1
# repeated guest index - 38931 , value - 1
# repeated guest index - 38973 , value - 1
# repeated guest index - 39168 , value - 1
# repeated guest index - 39333 , value - 1
# repeated guest index - 39378 , value - 1
# repeated guest index - 39403 , value - 1
# repeated guest index - 39538 , value - 1
# repeated guest index - 39623 , value - 1
# repeated guest index - 39634 , value - 1
# repeated guest index - 39641 , value - 1
# repeated guest index - 39707 , value - 1
# repeated guest index - 39755 , value - 1
# repeated guest index - 40405 , value - 1
# repeated guest index - 40424 , value - 1
# repeated guest index - 40483 , value - 1
# repeated guest index - 41054 , value - 1
# repeated guest index - 41055 , value - 1
# repeated guest index - 41083 , value - 1
# repeated guest index - 41100 , value - 1
# repeated guest index - 41128 , value - 1
# repeated guest index - 41185 , value - 1
# repeated guest index - 41489 , value - 1
# repeated guest index - 41502 , value - 1
# repeated guest index - 41693 , value - 1
# repeated guest index - 42000 , value - 1
# repeated guest index - 42171 , value - 1
# repeated guest index - 42319 , value - 1
# repeated guest index - 42450 , value - 1
# repeated guest index - 42453 , value - 1
# repeated guest index - 42513 , value - 1
# repeated guest index - 42764 , value - 1
# repeated guest index - 42916 , value - 1
# repeated guest index - 42946 , value - 1
# repeated guest index - 43049 , value - 1
# repeated guest index - 43149 , value - 1
# repeated guest index - 43191 , value - 1
# repeated guest index - 43213 , value - 1
# repeated guest index - 43255 , value - 1
# repeated guest index - 43423 , value - 1
# repeated guest index - 43467 , value - 1
# repeated guest index - 43475 , value - 1
# repeated guest index - 43542 , value - 1
# repeated guest index - 43680 , value - 1
# repeated guest index - 43681 , value - 1
# repeated guest index - 43732 , value - 1
# repeated guest index - 43764 , value - 1
# repeated guest index - 43822 , value - 1
# repeated guest index - 43933 , value - 1
# repeated guest index - 44054 , value - 1
# repeated guest index - 44103 , value - 1
# repeated guest index - 44154 , value - 1
# repeated guest index - 44328 , value - 1
# repeated guest index - 45006 , value - 1
# repeated guest index - 45091 , value - 1
# repeated guest index - 45300 , value - 1
# repeated guest index - 45411 , value - 1
# repeated guest index - 45649 , value - 1
# repeated guest index - 45676 , value - 1
# repeated guest index - 45766 , value - 1
# repeated guest index - 46063 , value - 1
# repeated guest index - 46159 , value - 1
# repeated guest index - 46232 , value - 1
# repeated guest index - 46492 , value - 1
# repeated guest index - 46502 , value - 1
# repeated guest index - 46505 , value - 1
# repeated guest index - 46794 , value - 1
# repeated guest index - 46830 , value - 1
# repeated guest index - 46930 , value - 1
# repeated guest index - 47052 , value - 1
# repeated guest index - 47127 , value - 1
# repeated guest index - 47175 , value - 1
# repeated guest index - 47201 , value - 1
# repeated guest index - 47271 , value - 1
# repeated guest index - 47454 , value - 1
# repeated guest index - 47483 , value - 1
# repeated guest index - 47736 , value - 1
# repeated guest index - 47977 , value - 1
# repeated guest index - 48006 , value - 1
# repeated guest index - 48038 , value - 1
# repeated guest index - 48099 , value - 1
# repeated guest index - 48352 , value - 1
# repeated guest index - 48486 , value - 1
# repeated guest index - 48602 , value - 1
# repeated guest index - 48634 , value - 1
# repeated guest index - 48769 , value - 1
# repeated guest index - 48838 , value - 1
# repeated guest index - 48928 , value - 1
# repeated guest index - 48991 , value - 1
# repeated guest index - 49175 , value - 1
# repeated guest index - 49191 , value - 1
# repeated guest index - 49463 , value - 1
# repeated guest index - 49472 , value - 1
# repeated guest index - 49475 , value - 1
# repeated guest index - 49633 , value - 1
# repeated guest index - 49892 , value - 1
# repeated guest index - 50265 , value - 1
# repeated guest index - 50282 , value - 1
# repeated guest index - 50304 , value - 1
# repeated guest index - 50429 , value - 1
# repeated guest index - 50575 , value - 1
# repeated guest index - 50622 , value - 1
# repeated guest index - 50633 , value - 1
# repeated guest index - 50698 , value - 1
# repeated guest index - 50870 , value - 1
# repeated guest index - 50889 , value - 1
# repeated guest index - 51259 , value - 1
# repeated guest index - 51426 , value - 1
# repeated guest index - 51584 , value - 1
# repeated guest index - 51636 , value - 1
# repeated guest index - 51828 , value - 1
# repeated guest index - 51875 , value - 1
# repeated guest index - 51940 , value - 1
# repeated guest index - 52053 , value - 1
# repeated guest index - 52062 , value - 1
# repeated guest index - 52408 , value - 1
# repeated guest index - 52464 , value - 1
# repeated guest index - 52545 , value - 1
# repeated guest index - 52671 , value - 1
# repeated guest index - 52767 , value - 1
# repeated guest index - 52772 , value - 1
# repeated guest index - 52780 , value - 1
# repeated guest index - 52880 , value - 1
# repeated guest index - 52937 , value - 1
# repeated guest index - 53048 , value - 1
# repeated guest index - 53133 , value - 1
# repeated guest index - 53211 , value - 1
# repeated guest index - 53467 , value - 1
# repeated guest index - 53484 , value - 1
# repeated guest index - 53533 , value - 1
# repeated guest index - 53537 , value - 1
# repeated guest index - 53626 , value - 1
# repeated guest index - 53749 , value - 1
# repeated guest index - 53831 , value - 1
# repeated guest index - 53839 , value - 1
# repeated guest index - 53874 , value - 1
# repeated guest index - 53967 , value - 1
# repeated guest index - 53987 , value - 1
# repeated guest index - 54026 , value - 1
# repeated guest index - 54081 , value - 1
# repeated guest index - 54157 , value - 1
# repeated guest index - 54217 , value - 1
# repeated guest index - 54466 , value - 1
# repeated guest index - 54538 , value - 1
# repeated guest index - 54707 , value - 1
# repeated guest index - 54817 , value - 1
# repeated guest index - 54901 , value - 1
# repeated guest index - 54940 , value - 1
# repeated guest index - 55032 , value - 1
# repeated guest index - 55061 , value - 1
# repeated guest index - 55110 , value - 1
# repeated guest index - 55349 , value - 1
# repeated guest index - 55365 , value - 1
# repeated guest index - 56010 , value - 1
# repeated guest index - 56020 , value - 1
# repeated guest index - 56309 , value - 1
# repeated guest index - 56343 , value - 1
# repeated guest index - 56413 , value - 1
# repeated guest index - 56503 , value - 1
# repeated guest index - 56539 , value - 1
# repeated guest index - 56696 , value - 1
# repeated guest index - 56759 , value - 1
# repeated guest index - 57154 , value - 1
# repeated guest index - 57186 , value - 1
# repeated guest index - 57600 , value - 1
# repeated guest index - 57991 , value - 1
# repeated guest index - 57993 , value - 1
# repeated guest index - 58015 , value - 1
# repeated guest index - 58046 , value - 1
# repeated guest index - 58062 , value - 1
# repeated guest index - 58104 , value - 1
# repeated guest index - 58286 , value - 1
# repeated guest index - 58491 , value - 1
# repeated guest index - 58591 , value - 1
# repeated guest index - 59012 , value - 1
# repeated guest index - 59140 , value - 1
# repeated guest index - 59176 , value - 1
# repeated guest index - 59360 , value - 1
# repeated guest index - 59394 , value - 1
# repeated guest index - 59395 , value - 1
# repeated guest index - 59428 , value - 1
# repeated guest index - 59572 , value - 1
# repeated guest index - 59591 , value - 1
# repeated guest index - 59674 , value - 1
# repeated guest index - 59717 , value - 1
# repeated guest index - 59726 , value - 1
# repeated guest index - 59765 , value - 1
# repeated guest index - 59775 , value - 1
# repeated guest index - 59783 , value - 1
# repeated guest index - 59842 , value - 1
# repeated guest index - 60086 , value - 1
# repeated guest index - 60270 , value - 1
# repeated guest index - 60312 , value - 1
# repeated guest index - 60625 , value - 1
# repeated guest index - 60722 , value - 1
# repeated guest index - 60882 , value - 1
# repeated guest index - 61494 , value - 1
# repeated guest index - 61518 , value - 1
# repeated guest index - 61582 , value - 1
# repeated guest index - 61588 , value - 1
# repeated guest index - 61616 , value - 1
# repeated guest index - 61668 , value - 1
# repeated guest index - 61799 , value - 1
# repeated guest index - 61980 , value - 1
# repeated guest index - 62046 , value - 1
# repeated guest index - 62060 , value - 1
# repeated guest index - 62170 , value - 1
# repeated guest index - 62294 , value - 1
# repeated guest index - 62374 , value - 1
# repeated guest index - 62679 , value - 1
# repeated guest index - 62687 , value - 1
# repeated guest index - 62891 , value - 1
# repeated guest index - 62895 , value - 1
# repeated guest index - 62945 , value - 1
# repeated guest index - 63112 , value - 1
# repeated guest index - 63543 , value - 1
# repeated guest index - 63670 , value - 1
# repeated guest index - 63739 , value - 1
# repeated guest index - 63805 , value - 1
# repeated guest index - 63886 , value - 1
# repeated guest index - 63946 , value - 1
# repeated guest index - 64230 , value - 1
# repeated guest index - 64413 , value - 1
# repeated guest index - 64470 , value - 1
# repeated guest index - 64532 , value - 1
# repeated guest index - 64650 , value - 1
# repeated guest index - 64942 , value - 1
# repeated guest index - 65334 , value - 1
# repeated guest index - 65347 , value - 1
# repeated guest index - 65481 , value - 1
# repeated guest index - 65573 , value - 1
# repeated guest index - 65574 , value - 1
# repeated guest index - 65583 , value - 1
# repeated guest index - 65595 , value - 1
# repeated guest index - 65713 , value - 1
# repeated guest index - 65769 , value - 1
# repeated guest index - 65829 , value - 1
# repeated guest index - 65971 , value - 1
# repeated guest index - 66036 , value - 1
# repeated guest index - 66223 , value - 1
# repeated guest index - 66336 , value - 1
# repeated guest index - 66371 , value - 1
# repeated guest index - 66462 , value - 1
# repeated guest index - 66477 , value - 1
# repeated guest index - 66628 , value - 1
# repeated guest index - 66652 , value - 1
# repeated guest index - 66661 , value - 1
# repeated guest index - 66793 , value - 1
# repeated guest index - 67009 , value - 1
# repeated guest index - 67457 , value - 1
# repeated guest index - 67912 , value - 1
# repeated guest index - 67983 , value - 1
# repeated guest index - 68374 , value - 1
# repeated guest index - 68376 , value - 1
# repeated guest index - 68377 , value - 1
# repeated guest index - 68384 , value - 1
# repeated guest index - 68421 , value - 1
# repeated guest index - 68435 , value - 1
# repeated guest index - 68565 , value - 1
# repeated guest index - 68667 , value - 1
# repeated guest index - 68790 , value - 1
# repeated guest index - 69462 , value - 1
# repeated guest index - 69537 , value - 1
# repeated guest index - 69582 , value - 1
# repeated guest index - 69665 , value - 1
# repeated guest index - 69799 , value - 1
# repeated guest index - 69811 , value - 1
# repeated guest index - 69904 , value - 1
# repeated guest index - 70055 , value - 1
# repeated guest index - 70073 , value - 1
# repeated guest index - 70130 , value - 1
# repeated guest index - 70154 , value - 1
# repeated guest index - 70177 , value - 1
# repeated guest index - 70208 , value - 1
# repeated guest index - 70408 , value - 1
# repeated guest index - 70472 , value - 1
# repeated guest index - 70553 , value - 1
# repeated guest index - 70937 , value - 1
# repeated guest index - 70966 , value - 1
# repeated guest index - 71093 , value - 1
# repeated guest index - 71118 , value - 1
# repeated guest index - 71274 , value - 1
# repeated guest index - 71279 , value - 1
# repeated guest index - 71336 , value - 1
# repeated guest index - 71345 , value - 1
# repeated guest index - 71378 , value - 1
# repeated guest index - 71464 , value - 1

# %%
data[['weekend nights stays']].boxplot()
# Out:
# <AxesSubplot:>

# %%
data[['week nights stays']].boxplot()
# Out:
# <AxesSubplot:>

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1

# %%
data = data.loc[(data['weekend nights stays'] < (Q1['weekend nights stays'] - 1.5 * IQR['weekend nights stays'])) | (data['weekend nights stays'] > (Q3['weekend nights stays'] + 1.5 * IQR['weekend nights stays']))]

# %%
data.boxplot('weekend nights stays')
# Out:
# <AxesSubplot:>

# %%
data = data.loc[(data['week nights stays'] < (Q1['week nights stays'] - 1.5 * IQR['week nights stays'])) | (data['week nights stays'] > (Q3['week nights stays'] + 1.5 * IQR['week nights stays']))]

# %%
data[['week nights stays']].boxplot()
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['ID', 'hotel', 'canceled', 'year', 'month', 'week number', 'day',
#        'weekend nights stays', 'week nights stays', 'adults', 'children',
#        'meal', 'country', 'repeated guest', 'deposit', 'agent', 'customer',
#        'reservation status', 'reservation status date'],
#       dtype='object')

# %%
i = 0
while i < data.shape[1]: 
 if (data.iloc[:, i].dtype == 'object'):
  print(data[str(data.iloc[:, i].name)].name)
 i += 1
# Out:
# hotel
# month
# meal
# country
# deposit
# customer
# reservation status
# reservation status date

# %%
cat = ['hotel', 'month', 'meal', 'country', 'deposit', 'customer', 'reservation status', 'reservation status date']

# %%
i = 0
while i < data.shape[1]: 
 if (data.iloc[:, i].dtype == 'int64' or data.iloc[:, i].dtype == 'float64'):
  print(data[str(data.iloc[:, i].name)].name)
 i += 1
# Out:
# ID
# canceled
# year
# week number
# day
# weekend nights stays
# week nights stays
# adults
# children
# repeated guest
# agent

# %%
num = ['ID', 'canceled', 'year', 'week number', 'day', 'weekend nights stays', 'week nights stays', 'adults', 'children', 'repeated guest', 'agent']

# %%
X = data[['ID', 'canceled', 'year', 'week number', 'day', 'week nights stays', 'adults', 'children', 'repeated guest', 'agent']].copy()

# %%
Y = data[['weekend nights stays']].copy()

# %%
data.shape
# Out:
# (117, 19)

# %%
X.shape, Y.shape
# Out:
# ((117, 10), (117, 1))

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state= 30)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((81, 10), (81, 1), (36, 10), (36, 1))

# %%
x_train_ols =  sm.add_constant(x_train)

# %%
ols_model = sm.OLS(y_train, x_train, missing="drop").fit()

# %%
y_predicted_ols=ols_model.predict(x_test)

# %%
y_predicted_ols.shape, y_test.shape
# Out:
# ((36,), (36, 1))

# %%
lr_model = linear_model.LinearRegression()

# %%
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predicted_ls = lr_model.predict(x_test)

# %%
print("MSE of OLS() vs LinearRegression():\n")
mean_squared_error(y_test, y_predicted_ols), mean_squared_error(y_test, y_predicted_ls)
# Out:
# MSE of OLS() vs LinearRegression():
# (0.49345907972157715, 0.49380763094393676)

# %%
print("R-square of OLS() vs LinearRegression():\n")
r2_score(y_test, y_predicted_ols), r2_score(y_test, y_predicted_ls)
# Out:
# R-square of OLS() vs LinearRegression():
# (0.8348339443907118, 0.8347172805518228)

# %%
lr_model.coef_
# Out:
# array([[-1.81109670e-06,  1.11522234e-02, -4.50122224e-02,
#          7.18385999e-03,  2.32475158e-02,  3.82623782e-01,
#         -7.32213116e-02,  1.83597072e-01,  0.00000000e+00,
#         -2.74059127e-03]])

# %%
lr_model.intercept_
# Out:
# array([91.27538898])

# %%
#OSI
x1 = y_test.values
y1 = y_predicted_ols.values
x1 = x1.flatten()
y1 = y1.flatten()

xs = np.linspace(-0.25, 9.25, 200)

lin = np.polyfit(x1, y1, 1)
quad = np.polyfit(x1, y1, 2)
many = np.polyfit(x1, y1, 9)

plt.scatter(x1, y1)
plt.plot(xs, poly1d(lin)(xs))
plt.plot(xs, poly1d(quad)(xs))
plt.plot(xs, poly1d(many)(xs))
plt.ylabel('Y')
plt.xlabel('X')
plt.legend(['Underfit', 'Good fit', 'Overfit']);
# Out:
# c:\users\dushu\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#LS
x2 = y_test.values
y2 = y_predicted_ls.ravel()
x2 = x2.flatten()

xs = np.linspace(-0.05, 8.25, 100)

lin = np.polyfit(x2, y2, 1)
quad = np.polyfit(x2, y2, 4)
many = np.polyfit(x2, y2, 9)

plt.scatter(x2, y2)
plt.plot(xs, poly1d(lin)(xs))
plt.plot(xs, poly1d(quad)(xs))
plt.plot(xs, poly1d(many)(xs))
plt.ylabel('Y')
plt.xlabel('X')
plt.legend(['Underfit', 'Good fit', 'Overfit']);
# Out:
# c:\users\dushu\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
LabelEncoder_ = preprocessing.LabelEncoder()
i = 0
while i < data.shape[1]: 
 if (data.iloc[:, i].dtype == 'object'):
  data[str(data.iloc[:, i].name)] = LabelEncoder_.fit_transform(data[str(data.iloc[:, i].name)])
 i += 1

# %%
clf = Perceptron(fit_intercept=False, max_iter=10, tol=None,
                 shuffle=False).fit(PolynomialFeatures().fit_transform(x_train).astype(int), y_train.values.ravel())

# %%
clf.predict(PolynomialFeatures().fit_transform(x_train).astype(int))
# Out:
# array([6, 6, 6, 8, 6, 6, 6, 6, 6, 6, 8, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 8, 6, 6, 6, 6, 6, 6, 8, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6], dtype=int64)

# %%
clf.score(PolynomialFeatures().fit_transform(x_train).astype(int), y_train.values.ravel())
# Out:
# 0.6172839506172839

# %%
# train LinearRegression model
lr_model = linear_model.LinearRegression()
lr_model.fit(PolynomialFeatures().fit_transform(x_train).astype(int), y_train.values.ravel())
y_predicted_ls = lr_model.predict(PolynomialFeatures().fit_transform(x_train).astype(int))

# %%
# predict with OLS
x_train_ols =  sm.add_constant(PolynomialFeatures().fit_transform(x_train).astype(int))
ols_model = sm.OLS(y_train, x_train, missing="drop").fit()
y_predicted_ols=ols_model.predict(x_test)

# %%
# compare their metrics
print("MSE of OLS() vs LinearRegression():\n")
mean_squared_error(y_test, y_predicted_ols), mean_squared_error(y_train.values.ravel(), y_predicted_ls)
# Out:
# MSE of OLS() vs LinearRegression():
# (0.49345907972157715, 0.19036175414382517)

# %%
print("R-square of OLS() vs LinearRegression():\n")
r2_score(y_test, y_predicted_ols), r2_score(y_train.values.ravel(), y_predicted_ls)
# Out:
# R-square of OLS() vs LinearRegression():
# (0.8348339443907118, 0.9234797531590714)
