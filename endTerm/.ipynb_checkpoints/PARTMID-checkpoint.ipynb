# %%
import matplotlib.pyplot as plt
import pandas as pd
import math 
from random import randrange
import pandas.util.testing as tm
import numpy  as np
import seaborn as sns
from sklearn import linear_model
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from statsmodels import regression
from scipy import poly1d
from sklearn.linear_model import Perceptron
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest, f_regression
import os
import pydotplus
import graphviz 
from random import randrange
from sklearn import tree
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

# %%
-----------------------------------------------Kalzhigitov_Nurbol_ITSE-1908R----------------------------------------------------

# %%
1st STEP --------------------------------------Take a first look at your data---------------------------------------------------

# %%
data = pd.read_csv('Part_II.csv')

# %%
# %matplotlib inline

# %%
data.head(10)
# Out:
#    id           name  Gender Eye color               Race Hair color  Height  \
# 0   0         A-Bomb    Male    yellow              Human    No Hair   203.0
# 1   1     Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# 2   2       Abin Sur    Male      blue            Ungaran    No Hair   185.0
# 3   3    Abomination    Male     green  Human / Radiation    No Hair   203.0
# 4   4        Abraxas    Male      blue      Cosmic Entity      Black   -99.0
# 5   5  Absorbing Man    Male      blue              Human    No Hair   193.0
# 6   6    Adam Monroe    Male      blue                  -      Blond   -99.0
# 7   7   Adam Strange    Male      blue              Human      Blond   185.0
# 8   8       Agent 13  Female      blue                  -      Blond   173.0
# 9   9      Agent Bob    Male     brown              Human      Brown   178.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0
# 5      Marvel Comics          -       bad   122.0
# 6       NBC - Heroes          -      good   -99.0
# 7          DC Comics          -      good    88.0
# 8      Marvel Comics          -      good    61.0
# 9      Marvel Comics          -      good    81.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          734 non-null    int64
#  1   name        734 non-null    object
#  2   Gender      734 non-null    object
#  3   Eye color   734 non-null    object
#  4   Race        734 non-null    object
#  5   Hair color  734 non-null    object
#  6   Height      734 non-null    float64
#  7   Publisher   719 non-null    object
#  8   Skin color  734 non-null    object
#  9   Alignment   734 non-null    object
#  10  Weight      732 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 40.2+ KB

# %%
data.describe()
# Out:
#                id      Height      Weight
# count  734.000000  734.000000  732.000000
# mean   366.500000  102.254087   43.855191
# std    212.031837  139.624543  130.823733
# min      0.000000  -99.000000  -99.000000
# 25%    183.250000  -99.000000  -99.000000
# 50%    366.500000  175.000000   62.000000
# 75%    549.750000  185.000000   90.000000
# max    733.000000  975.000000  900.000000

# %%
i = 0
j = 0
while i < data.shape[1]: 
 if (data.iloc[:, i].dtype == 'int64' or data.iloc[:, i].dtype == 'float64'):
  j += 1
 i += 1
print('numerical -', j)
# Out:
# numerical - 3

# %%
i = 0
j = 0
while i < data.shape[1]: 
 if (data.iloc[:, i].dtype == 'object'):
  j += 1
 i += 1
print('categorical -', j)
# Out:
# categorical - 8

# %%
i = 0
sum = 0
while i < data.shape[1]:  
 if (data[str(data.iloc[:, i].name)].isnull().any()):   
  print('column -',str(data.iloc[:, i].name),' - have:', data[str(data.iloc[:, i].name)].isnull().sum(), 'NaN Data')
 sum += data[str(data.iloc[:, i].name)].isna().sum()
 i += 1 
print('Total NaNs -', sum)
# Out:
# column - Publisher  - have: 15 NaN Data
# column - Weight  - have: 2 NaN Data
# Total NaNs - 17

# %%
i = 0
sum = 0
while i < data.shape[1]:  
 if (data[str(data.iloc[:, i].name)].isnull().any()):   
  percent_missing = data[str(data.iloc[:, i].name)].isna().sum() * 100 / len(data)
  print('column -',str(data.iloc[:, i].name),' - have:', percent_missing, '%')
 i += 1
print(len(data))
# Out:
# column - Publisher  - have: 2.043596730245232 %
# column - Weight  - have: 0.2724795640326976 %
# 734

# %%
data.shape
# Out:
# (734, 11)

# %%
data_num = data.select_dtypes('number')
plt.figure(figsize=(30,30))
dataVisualSt = data_num .corr()
mask = np.triu(np.ones_like(dataVisualSt, dtype=bool))
cmap = sns.diverging_palette(110, 10, as_cmap=True)
sns.heatmap(dataVisualSt, annot=True, mask=mask, cmap=cmap, vmin=0, vmax=1, center=0, fmt=".2f", square=True, linewidths=.99, cbar_kws={"shrink": .99})
# Out:
# <AxesSubplot:>

# %%
1st STEP ------------------------------------------Data prepatation-------------------------------------------------------------

# %%
First of all we divided our data in two new data set, 
first primordial one that we use for our Dummy model and, 
second that we use in point 5 to improve our model.

# %%
----------------------------------------------------Preparing a set-------------------------------------------------------------

# %%
df = pd.DataFrame()
i = 0
j = 0
while i < data.shape[1]: 
 if (data.iloc[:, i].dtype == 'int64' or data.iloc[:, i].dtype == 'float64'):
  df[str(data.iloc[:, i].name)] = data[str(data.iloc[:, i].name)]
 i += 1

# %%
df.head()
# Out:
#    id  Height  Weight
# 0   0   203.0   441.0
# 1   1   191.0    65.0
# 2   2   185.0    90.0
# 3   3   203.0   441.0
# 4   4   -99.0   -99.0

# %%
dataImprove = data.copy()

# %%
dataImprove.shape
# Out:
# (734, 11)

# %%
dataImprove.head()
# Out:
#    id         name Gender Eye color               Race Hair color  Height  \
# 0   0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2   2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3   3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4   4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %%
----------------------------------------------------Restoring Nans Values-------------------------------------------------------

# %%
i = 0
while i < dataImprove.shape[1]: 
 if (dataImprove.iloc[:, i].dtype == 'int64' or dataImprove.iloc[:, i].dtype == 'float64'):
  data[str(dataImprove.iloc[:, i].name)].fillna(dataImprove[str(dataImprove.iloc[:, i].name)].median(), inplace=True)
 i += 1

# %%
dataImprove.head(10)
# Out:
#    id           name  Gender Eye color               Race Hair color  Height  \
# 0   0         A-Bomb    Male    yellow              Human    No Hair   203.0
# 1   1     Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# 2   2       Abin Sur    Male      blue            Ungaran    No Hair   185.0
# 3   3    Abomination    Male     green  Human / Radiation    No Hair   203.0
# 4   4        Abraxas    Male      blue      Cosmic Entity      Black   -99.0
# 5   5  Absorbing Man    Male      blue              Human    No Hair   193.0
# 6   6    Adam Monroe    Male      blue                  -      Blond   -99.0
# 7   7   Adam Strange    Male      blue              Human      Blond   185.0
# 8   8       Agent 13  Female      blue                  -      Blond   173.0
# 9   9      Agent Bob    Male     brown              Human      Brown   178.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0
# 5      Marvel Comics          -       bad   122.0
# 6       NBC - Heroes          -      good   -99.0
# 7          DC Comics          -      good    88.0
# 8      Marvel Comics          -      good    61.0
# 9      Marvel Comics          -      good    81.0

# %%
-------------------------------------------------Dropping Categorical Nans------------------------------------------------------

# %%
dataImprove = dataImprove.dropna(axis='rows')

# %%
dataImprove.isnull().sum()
# Out:
# id            0
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        0
# dtype: int64

# %%
dataImprove.shape
# Out:
# (719, 11)

# %%
dataImprove.head(10)
# Out:
#    id           name  Gender Eye color               Race Hair color  Height  \
# 0   0         A-Bomb    Male    yellow              Human    No Hair   203.0
# 1   1     Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# 2   2       Abin Sur    Male      blue            Ungaran    No Hair   185.0
# 3   3    Abomination    Male     green  Human / Radiation    No Hair   203.0
# 4   4        Abraxas    Male      blue      Cosmic Entity      Black   -99.0
# 5   5  Absorbing Man    Male      blue              Human    No Hair   193.0
# 6   6    Adam Monroe    Male      blue                  -      Blond   -99.0
# 7   7   Adam Strange    Male      blue              Human      Blond   185.0
# 8   8       Agent 13  Female      blue                  -      Blond   173.0
# 9   9      Agent Bob    Male     brown              Human      Brown   178.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0
# 5      Marvel Comics          -       bad   122.0
# 6       NBC - Heroes          -      good   -99.0
# 7          DC Comics          -      good    88.0
# 8      Marvel Comics          -      good    61.0
# 9      Marvel Comics          -      good    81.0

# %%
----Drop if value is '-'

# %%
i = 0
while i < dataImprove.shape[1]:  
 if (dataImprove.iloc[:, i].dtype == 'object'):
  for k in dataImprove[str(dataImprove.iloc[:, i].name)].index:
    if (dataImprove[str(dataImprove.iloc[:, i].name)][k] == '-'):
      print(k)
      dataImprove.drop(k, axis=0, inplace = True)
 i += 1
# Out:
# 87
# 112
# 133
# 134
# 160
# 165
# 178
# 196
# 234
# 249
# 253
# 257
# 261
# 267
# 269
# 280
# 409
# 410
i = 0
while i < dataImprove.shape[1]: 
 if (dataImprove.iloc[:, i].dtype == 'object'):
  dataImprove[str(dataImprove.iloc[:, i].name)] = LabelEncoder_.fit_transform(dataImprove[str(dataImprove.iloc[:, i].name)])
 i += 1

# %%
dataImprove.head(10)
# Out:
#       id  name  Gender  Eye color  Race  Hair color  Height  Publisher  \
# 1      1     0       1          1    14           7   191.0          1
# 2      2     1       1          1    27           7   185.0          0
# 34    34     2       1          7    21           1   213.0          4
# 39    39     3       1          1    21           2   183.0          4
# 41    41     4       0          8     0           8   193.0          4
# 56    56     5       1          9    23           1   183.0          4
# 74    74     6       1          1    21           3   180.0          4
# 75    75     7       1          4     9           5   173.0          0
# 92    92     8       1          0     2           1   191.0          0
# 108  108     9       1          7     5          13   191.0          4
#
#      Skin color  Alignment  Weight
# 1             0          1    65.0
# 2             9          1    90.0
# 34            5          0   135.0
# 39            0          1    68.0
# 41            2          1    98.0
# 56            9          0    67.0
# 74            0          1   181.0
# 75            4          1    68.0
# 92           11          2   155.0
# 108          11          0   104.0

# %%
----------------------------------------------------Rid Of Useless Data---------------------------------------------------------

# %%
dataImprove = dataImprove.drop(['id'], axis=1)

# %%
dataImprove.head(10)
# Out:
#      name  Gender  Eye color  Race  Hair color  Height  Publisher  Skin color  \
# 1       0       1          1    14           7   191.0          1           0
# 2       1       1          1    27           7   185.0          0           9
# 34      2       1          7    21           1   213.0          4           5
# 39      3       1          1    21           2   183.0          4           0
# 41      4       0          8     0           8   193.0          4           2
# 56      5       1          9    23           1   183.0          4           9
# 74      6       1          1    21           3   180.0          4           0
# 75      7       1          4     9           5   173.0          0           4
# 92      8       1          0     2           1   191.0          0          11
# 108     9       1          7     5          13   191.0          4          11
#
#      Alignment  Weight
# 1            1    65.0
# 2            1    90.0
# 34           0   135.0
# 39           1    68.0
# 41           1    98.0
# 56           0    67.0
# 74           1   181.0
# 75           1    68.0
# 92           2   155.0
# 108          0   104.0

# %%
dataImprove.shape
# Out:
# (59, 10)

# %%
--------------------------------------------------Getting rid of outliers-------------------------------------------------------

# %%
Before---

# %%
plt.figure(figsize=(30,30))
ax = sns.boxplot(data=dataImprove, orient="T", palette="Set2")

# %%
Fixing---

# %%
Q1 = dataImprove.quantile(0.25)
Q3 = dataImprove.quantile(0.75)
IQR = Q3 - Q1
i = 0
j = 0
k = 0
s = 0
while i < dataImprove.shape[1]:  
 if (dataImprove.iloc[:, i].dtype == 'int64' or dataImprove.iloc[:, i].dtype == 'float64'):
  dataTrueLess = dataImprove[str(dataImprove.iloc[:, i].name)] < (Q1[str(dataImprove.iloc[:, i].name)] - (1.5 * IQR[str(dataImprove.iloc[:, i].name)]))
  for k in dataTrueLess.index:
    if (dataTrueLess[k]): 
      dataImprove.drop(k, axis=0, inplace = True)
 i += 1 
while j < dataImprove.shape[1]:  
 if (dataImprove.iloc[:, j].dtype == 'int64' or dataImprove.iloc[:, j].dtype == 'float64'): 
  dataTrueMore = dataImprove[str(dataImprove.iloc[:, j].name)] > (Q3[str(dataImprove.iloc[:, j].name)] + (1.5 * IQR[str(dataImprove.iloc[:, j].name)]))
  for s in dataTrueMore.index:
    if (dataTrueMore[s]): 
      dataImprove.drop(s, axis=0, inplace = True)
 j += 1

# %%
After---

# %%
plt.figure(figsize=(30,30))
ax = sns.boxplot(data=dataImprove, orient="T", palette="Set2")

# %%
dataImprove.columns
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %%
-----------------------------------------------Detecting features and target values---------------------------------------------

# %%
1st set---

# %%
features = df.columns
features = features.tolist()
features.remove('Weight')
features = df[features]
features
# Out:
#       id  Height
# 0      0   203.0
# 1      1   191.0
# 2      2   185.0
# 3      3   203.0
# 4      4   -99.0
# ..   ...     ...
# 729  729   165.0
# 730  730   304.8
# 731  731    66.0
# 732  732   170.0
# 733  733   185.0
#
# [734 rows x 2 columns]

# %%
target = df.Weight
target
# Out:
# 0      441.0
# 1       65.0
# 2       90.0
# 3      441.0
# 4      -99.0
#        ...
# 729     52.0
# 730    -99.0
# 731     17.0
# 732     57.0
# 733     81.0
# Name: Weight, Length: 734, dtype: float64

# %%
2nd set---

# %%
featuresImprove = dataImprove.columns
featuresImprove = featuresImprove.tolist()
featuresImprove.remove('Weight')
featuresImprove = dataImprove[featuresImprove]
featuresImprove
# Out:
#      name  Gender  Eye color  Race  Hair color  Height  Publisher  Skin color  \
# 1       0       1          1    14           7   191.0          1           0
# 2       1       1          1    27           7   185.0          0           9
# 34      2       1          7    21           1   213.0          4           5
# 39      3       1          1    21           2   183.0          4           0
# 41      4       0          8     0           8   193.0          4           2
# 56      5       1          9    23           1   183.0          4           9
# 74      6       1          1    21           3   180.0          4           0
# 75      7       1          4     9           5   173.0          0           4
# 92      8       1          0     2           1   191.0          0          11
# 108     9       1          7     5          13   191.0          4          11
# 114    10       0          4    21           6   165.0          4           7
# 135    11       1          4     1           7   198.0          0           4
# 149    12       1          1    12          12   193.0          0          10
# 166    13       1          8     0          13   201.0          4           5
# 185    14       0          7    21          13   183.0          4           0
# 226    16       0          1     9           1   173.0          4          11
# 245    20       1          7     5           7   193.0          0          12
# 247    21       1          7     0           1   191.0          4           4
# 248    22       1          1    21           1   183.0          4           9
# 274    24       0          9    29           1   183.0          4           4
# 369    27       1          4     9           5   196.0          0          11
# 392    32       1          7     9           7   188.0          4           9
# 431    35       0          4    13           1   168.0          4           4
# 432    36       1          7    19           7   201.0          0           4
# 480    37       0         10    21          11   178.0          4           0
# 487    38       0          1    18           7   185.0          4           0
# 497    39       0          8    11          10   163.0          4           2
# 523    40       0          4     9          10   168.0          0           4
# 533    41       1          6     9           9   180.0          4           8
# 587    43       0          0    25           1   173.0          0           0
# 600    44       1          8     0           7   193.0          4          10
# 603    45       1          0    17           1   201.0          0           9
# 634    47       0          4    26           0   193.0          0           6
# 639    48       1          7    22           1   183.0          0          11
# 648    50       1          9    21           7   196.0          4          12
# 668    52       1          5     9           7   185.0          4           5
# 672    53       1          0    21           4   175.0          4           4
# 679    55       1          4    15           7   188.0          4           4
# 699    56       1          3     1           7   191.0          4           9
#
#      Alignment
# 1            1
# 2            1
# 34           0
# 39           1
# 41           1
# 56           0
# 74           1
# 75           1
# 92           2
# 108          0
# 114          1
# 135          0
# 149          1
# 166          1
# 185          2
# 226          1
# 245          2
# 247          0
# 248          0
# 274          1
# 369          0
# 392          0
# 431          1
# 432          1
# 480          0
# 487          0
# 497          1
# 523          0
# 533          0
# 587          1
# 600          1
# 603          2
# 634          1
# 639          0
# 648          0
# 668          0
# 672          2
# 679          1
# 699          1

# %%
targetImprove = dataImprove.Weight
targetImprove
# Out:
# 1       65.0
# 2       90.0
# 34     135.0
# 39      68.0
# 41      98.0
# 56      67.0
# 74     181.0
# 75      68.0
# 92     155.0
# 108    104.0
# 114     56.0
# 135    135.0
# 149     90.0
# 166     97.0
# 185     67.0
# 226     54.0
# 245    203.0
# 247    106.0
# 248     88.0
# 274     77.0
# 369     86.0
# 392     97.0
# 431     52.0
# 432    135.0
# 480     54.0
# 487     83.0
# 497     59.0
# 523     50.0
# 533     74.0
# 587     54.0
# 600    101.0
# 603     92.0
# 634     71.0
# 639     91.0
# 648     47.0
# 668    203.0
# 672     76.0
# 679     86.0
# 699    135.0
# Name: Weight, dtype: float64

# %%
--------------------------------------------------------Train and Test----------------------------------------------------------

# %%
1st------

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state= 30)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((513, 2), (513,), (221, 2), (221,))

# %%
2nd------

# %%
xImprove_train, xImprove_test, yImprove_train, yImprove_test = train_test_split(featuresImprove, targetImprove, test_size=0.3, random_state= 30)

# %%
xImprove_train.shape, yImprove_train.shape, xImprove_test.shape, yImprove_test.shape
# Out:
# ((31, 9), (31,), (8, 9), (8,))

# %%
3rd STEP ----------------------------------------Creating Dummy Model-----------------------------------------------------------

# %%
df.corr()
# Out:
#               id    Height    Weight
# id      1.000000  0.042915  0.065034
# Height  0.042915  1.000000  0.683143
# Weight  0.065034  0.683143  1.000000

# %%
sns.scatterplot(x = df['Height'], y = df['Weight'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
df['Square'] = (df['Height']**3)

# %%
df['Weight_fix'] = np.log(df.Weight)

# %%
sns.scatterplot(x = df.Square, y = df.Weight_fix)
# Out:
# <AxesSubplot:xlabel='Square', ylabel='Weight_fix'>

# %%
Dummy_Model = LinearRegression()

# %%
Dummy_Model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predicted_dummy = Dummy_Model.predict(x_test)

# %%
metrics.r2_score(y_test, y_predicted_dummy)
# Out:
# 0.4854416001408508

# %%
metrics.mean_squared_error(y_test, y_predicted_dummy)
# Out:
# 9693.131054307518

# %%
-----------------------------------------------------Improving the model--------------------------------------------------------

# %%
data_num = dataImprove.select_dtypes('number')
plt.figure(figsize=(30,30))
dataVisualSt = data_num .corr()
mask = np.triu(np.ones_like(dataVisualSt, dtype=bool))
cmap = sns.diverging_palette(110, 10, as_cmap=True)
sns.heatmap(dataVisualSt, annot=True, mask=mask, cmap=cmap, vmin=0, vmax=1, center=0, fmt=".2f", square=True, linewidths=.99, cbar_kws={"shrink": .99})
# Out:
# <AxesSubplot:>

# %%
----2nd Data Set

# %%
Dummy_ModelImprove = LinearRegression()

# %%
Dummy_ModelImprove.fit(xImprove_train, yImprove_train)
# 26  0.218437  0.000000   0.044808  0.061610    0.056009  0.912954   0.022404
# 27  0.221754  0.000000   0.022175  0.049895    0.055438  0.931366   0.000000
# 28  0.205422  0.005010   0.030062  0.045093    0.045093  0.901851   0.020041
# 29  0.228798  0.000000   0.000000  0.133022    0.005321  0.920512   0.000000
# 30  0.197532  0.004489   0.035915  0.000000    0.031426  0.866447   0.017957
# 31  0.198746  0.004417   0.000000  0.075082    0.004417  0.887731   0.000000
# 32  0.221001  0.000000   0.018809  0.122256    0.000000  0.907515   0.000000
# 33  0.226956  0.004728   0.033098  0.104022    0.004728  0.865270   0.000000
# 34  0.238754  0.004775   0.042976  0.100277    0.033426  0.935915   0.019100
# 35  0.185791  0.003573   0.017865  0.032156    0.025010  0.660988   0.014292
# 36  0.265986  0.005019   0.000000  0.105391    0.020074  0.878256   0.020074
# 37  0.256191  0.004658   0.018632  0.069870    0.032606  0.875708   0.018632
# 38  0.232527  0.004152   0.012457  0.004152    0.029066  0.793084   0.016609
#
#     Skin color  Alignment
# 0     0.000000   0.004941
# 1     0.043307   0.004812
# 2     0.019744   0.000000
# 3     0.000000   0.005091
# 4     0.009224   0.004612
# 5     0.045742   0.000000
# 6     0.000000   0.003902
# 7     0.021460   0.005365
# 8     0.044647   0.008118
# 9     0.050334   0.000000
# 10    0.039745   0.005678
# 11    0.016662   0.000000
# 12    0.046684   0.004668
# 13    0.022304   0.004461
# 14    0.000000   0.010147
# 15    0.060260   0.005478
# 16    0.042659   0.007110
# 17    0.018212   0.000000
# 18    0.043781   0.000000
# 19    0.019767   0.004942
# 20    0.050856   0.000000
# 21    0.041938   0.000000
# 22    0.022232   0.005558
# 23    0.016276   0.004069
# 24    0.000000   0.000000
# 25    0.000000   0.000000
# 26    0.011202   0.005601
# 27    0.022175   0.000000
# 28    0.040082   0.000000
# 29    0.000000   0.005321
# 30    0.044894   0.004489
# 31    0.039749   0.008833
# 32    0.028213   0.004702
# 33    0.052011   0.000000
# 34    0.057301   0.000000
# 35    0.017865   0.000000
# 36    0.020074   0.010037
# 37    0.018632   0.004658
# 38    0.037370   0.004152

# %%
targetN = DataNormalize.Weight
targetN
# Out:
# 0     0.321188
# 1     0.433073
# 2     0.533089
# 3     0.346174
# 4     0.451954
# 5     0.340527
# 6     0.706331
# 7     0.364822
# 8     0.629120
# 9     0.475889
# 10    0.317956
# 11    0.562339
# 12    0.420157
# 13    0.432695
# 14    0.339909
# 15    0.295820
# 16    0.721648
# 17    0.482612
# 18    0.428083
# 19    0.380508
# 20    0.397599
# 21    0.452000
# 22    0.289014
# 23    0.549312
# 24    0.282081
# 25    0.400504
# 26    0.330456
# 27    0.277192
# 28    0.370761
# 29    0.287328
# 30    0.453426
# 31    0.406325
# 32    0.333853
# 33    0.430271
# 34    0.224429
# 35    0.725301
# 36    0.381414
# 37    0.400590
# 38    0.560557
# Name: Weight, dtype: float64

# %%
----Using Cross Validation Score

# %%
scoreN = cross_val_score(Dummy_ModelImprove, featuresN, targetN, cv = 10)

# %%
scoreN.mean()
# Out:
# 0.8834432848006483

# %%
--------------------------------------------------------Summary-----------------------------------------------------------------
